# %% [markdown]
# <a href="https://colab.research.google.com/github/parfait2/2021-2-study/blob/master/%EC%82%B0%ED%95%99%ED%98%91%EB%A0%A5%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8_220406.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://davey.tistory.com/entry/Python-opencv-%EC%9D%B4%EC%9A%A9%ED%95%98%EC%97%AC-%EC%9D%B4%EB%AF%B8%EC%A7%80-%EA%B0%80%EC%9E%A5%EC%9E%90%EB%A6%AC-%EA%B2%80%EC%B6%9C%ED%95%98%EB%8A%94-%EB%B0%A9%EB%B2%95

# %%
from google.colab.patches import cv2_imshow

import cv2

test_image = cv2.imread("image.jpg", cv2.IMREAD_COLOR)

gray_tr01 = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)

method_canny = cv2.Canny(test_image, 100, 255)

method_sobel = cv2.Sobel(gray_tr01, cv2.CV_8U, 1, 0, 3)

method_laplacian = cv2.Laplacian(gray_tr01, cv2.CV_8U, ksize=3)


cv2_imshow(test_image)



'''
cv2_imshow(test_image)

cv2_imshow(method_canny)

cv2_imshow(method_sobel)

cv2_imshow(method_laplacian)
'''





'''
cv2.imshow("method_canny", method_canny)

cv2.imshow("method_sobel", method_sobel)

cv2.imshow("method_laplacian", method_laplacian)
'''
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=640x320 at 0x7F2C26FE4190>

# %% [markdown]
# https://076923.github.io/posts/Python-opencv-14/

# %%
import cv2

src = cv2.imread("image.jpg", cv2.IMREAD_COLOR)
gray = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)

sobel = cv2.Sobel(gray, cv2.CV_8U, 1, 0, 3)
laplacian = cv2.Laplacian(gray, cv2.CV_8U, ksize=3)
canny = cv2.Canny(src, 100, 255)

cv2_imshow(sobel)
cv2_imshow(laplacian)
cv2_imshow(canny)

'''
cv2_imshow(test_image)

cv2.imshow("laplacian", laplacian)
cv2.imshow("canny", canny)
'''
cv2.waitKey()
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=640x320 at 0x7F2C26FE9650>
# <PIL.Image.Image image mode=L size=640x320 at 0x7F2C26FE4210>
# <PIL.Image.Image image mode=L size=640x320 at 0x7F2C26FE42D0>

# %% [markdown]
# https://intrepidgeeks.com/tutorial/contour-discovery-function-for-python-opencv-image-edge-extraction

# %%
import cv2 as cv

src = cv.imread("image.jpg")

gray = cv.cvtColor(src, cv.COLOR_BGR2GRAY)
ret, thresh = cv.threshold(gray, 150, 255, 0)
cv2_imshow(thresh)
#     
contours, hierarchy = cv.findContours(thresh, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)
# Out:
# <PIL.Image.Image image mode=L size=640x320 at 0x7F2C26F443D0>

# %% [markdown]
# contours :윤곽
#
# contourIdx : 윤곽의 색인
#
# thickness : 두께
#
# hierarchy : 차원 구조의 선택 가능한 정보
#
# maxLevel : 윤곽의 최대 단계를 그린다.
#
# offset : 윤곽 오프셋 매개 변수.

# %%
from google.colab.patches import cv2_imshow

import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
# help(cv.drawContours)
src = cv.imread("image.jpg")

gray = cv.cvtColor(src, cv.COLOR_BGR2GRAY)
ret, thresh = cv.threshold(gray, 150, 255, 0)
cv2_imshow(thresh)
#     
contours, hierarchy = cv.findContours(thresh, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# print(contours)
# print(hierarchy)

cv.drawContours(src,contours,-1,(200,0,150),2)

cv2_imshow(src)

cv.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=640x320 at 0x7F2C26F44D50>
# <PIL.Image.Image image mode=RGB size=640x320 at 0x7F2C26F44D50>
# -1

# %%
#     
dst = cv2.fastNlMeansDenoisingColored(src,None,10,10,7,21)
plt.subplot(121),plt.imshow(src)
plt.subplot(122),plt.imshow(dst)
plt.show()

# 2 개의 컨투어 라인
len(contours)
## > 2

# 컨투어의 모양
contours[0].shape
## > (312, 1, 2)

# 컨투어 라인이 이어져있는 좌표정보
np.squeeze(contours[0])[:5]

# x좌표와 y좌표를 리스트로 받는다.
# x0, y0 = zip(*np.squeeze(contours[0])) # zip(*squeeze)를 하면 열로 잘린다.
# plt.plot(x0, y0, c="b")
# plt.show()
# Out:
# array([105, 246], dtype=int32)
